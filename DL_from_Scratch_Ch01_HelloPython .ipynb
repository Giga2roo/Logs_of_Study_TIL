# %% [markdown]
# ## Deep Learning from Scratch

# %% [markdown]
# ### 1장 - 헬로 파이썬

# %% [markdown]
# - 1.4.2 Class

# %%
class Man:
    def __init__(self, name):
        self.name = name
        print("Initialized!")

    def hello(self):
        print("Hello " + self.name + "!")

    def goodbye(self):
        print("Good-bye " + self.name + "!")

m = Man(input())
m.hello()
m.goodbye()

# %% [markdown]
# - 1.5.6 원소 접근

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 19.4 MB/s eta 0:00:0000:0100:01
# ...
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/Users/giga2roo/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
print(X)
X.shape, X.dtype, X[0], X[0][1]
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]
# ((3, 2), dtype('int64'), array([51, 55]), 55)

# %%
X1 = X.flatten()
print(X1)
# Out:
# [51 55 14 19  0  4]

# %%
X[X > 15]
# Out:
# array([51, 55, 19])

# %% [markdown]
# - 1.6.1 단순한 그래프 그리기

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 6, 0.1)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# - 1.6.2 pyplot의 기능

# %%
x = np.arange(0, 6, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label = "sin")
plt.plot(x, y2, linestyle="--", label="cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos graph')
plt.legend(loc='best') #https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html?highlight=pyplot%20legend#matplotlib.pyplot.legend
plt.show()

# %% [markdown]
# - 1.6.3 이미지 표시하기

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('dataset/ch01_01_Martha.jpeg')

plt.imshow(img)
plt.show()
